# %% [markdown]
# # Imports

# %%
import numpy as np 
import cv2 
import matplotlib.pyplot as plt
import PIL.Image as Image
import random
import gym

from gym import Env, spaces
import time
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

font = cv2.FONT_HERSHEY_COMPLEX_SMALL

# %% [markdown]
# # Vehicle Area Model in Discrete Space

# %%
class VehicleArea(Env):
    def __init__(self, four_only = True):
        super(VehicleArea, self).__init__()

        # Define action and observation space
        self.canvas_shape = (900, 900, 3)
        #self.observation_space = spaces.Box(low = np.zeros(self.observation_shape), 
        #                                                high = np.ones(self.observation_shape),
        #                                                dtype = np.uint8)
        self.observation_shape = (45, 45, 3)
        self.observation_space = spaces.Box(low = np.zeros(self.observation_shape, dtype=np.uint8),
                                            high= 255*np.ones(self.observation_shape, dtype=np.uint8),
                                            dtype=np.uint8)


        

        # Define an action space ranging from 0 to 3 ## 8
        if four_only:
            self.action_space = spaces.Discrete(4)
        else:
            self.action_space = spaces.Discrete(8)
        
        
        # Maximum fuel vehicle can take at once
        self.max_fuel = 1000

        # Define visted cells within the environment
        self.visited = []

        # Permitted area of the environment for the vehicle to not be placed out of bounds
        self.y_min = 0
        self.x_min = 0
        self.y_max = self.canvas_shape[0] #- 80
        self.x_max = self.canvas_shape[1] #- 80

                                
        # Create a canvas to render the environment images upon 
        self.canvas = np.ones(self.canvas_shape, dtype=np.uint8) * 255
    
    def draw_elements_on_canvas(self):
        # Init the canvas 
        self.canvas = np.ones(self.canvas_shape, dtype=np.uint8) * 255

        # Draw the elements on canvas
        for elem in self.visited:
            elem_shape = elem.icon.shape
            x,y = elem.x, elem.y
            self.canvas[y : y + elem_shape[1], x:x + elem_shape[0]] = elem.icon
        
        # Draw the vehicle on canvas
        self.canvas[self.vehicle.y : self.vehicle.y + self.vehicle.icon.shape[1], self.vehicle.x:self.vehicle.x + self.vehicle.icon.shape[0]] = self.vehicle.icon
        

        text = 'Fuel Left: {} | Return: {}'.format(self.fuel_left, self.ep_return)

        # Put the info on canvas 
        self.canvas = cv2.putText(self.canvas, text, (10,20), font,  
                   0.8, (0,0,0), 1, cv2.LINE_AA)

    
    def reset(self):
        # Reset the fuel consumed
        self.fuel_left = self.max_fuel
    
        # Reset the reward
        self.ep_return  = 0

        # Number of visited cells
        self.visited_count = 0
    
        # Determine a place to intialise the vehicle in the environment (top left corner)
        x = random.randrange(int(0), int(self.observation_shape[0]), 90)
        y = random.randrange(int(0), int(self.observation_shape[1]), 90)
        
        # Intialise the vehicle
        self.vehicle = Vehicle("vehicle", self.x_max, self.x_min, self.y_max, self.y_min)
        self.vehicle.set_position(x,y)

        
    
        # Intialise the elements 
        self.visited = [] # self.vehicle

        spawned_visit = Visited("visit_{}".format(self.visited_count), self.x_max, self.x_min, self.y_max, self.y_min)
        self.visited_count += 1
        spawned_visit.set_position(self.vehicle.x, self.vehicle.y)
        self.visited.append(spawned_visit)
    
        # Reset the Canvas 
        self.canvas = np.ones(self.canvas_shape) * 255

        # Draw elements on the canvas
        self.draw_elements_on_canvas()
    
        # return the observation
        #return self.canvas 
        #cv2.imshow("resized",cv2.resize(self.canvas, (45,45)))
        return cv2.resize(self.canvas, (45,45))
        



    def render(self, mode = "human"):
        assert mode in ["human", "rgb_array"], "Invalid mode, must be either \"human\" or \"rgb_array\""
        if mode == "human":
            cv2.imshow("Area To Cover", self.canvas)
            cv2.waitKey(10)
        
        elif mode == "rgb_array":
            return self.canvas
        
    def close(self):
        cv2.destroyAllWindows()

    def get_action_meanings(self):
        return {0: "Right", 1: "Left", 2: "Down", 3: "Up"}#, 4: "Do Nothing"}

    def step(self, action):
        # Flag that marks the termination of an episode
        done = False
        reward = 0

        # Assert that it is a valid action 
        assert self.action_space.contains(action), "Invalid Action"

        # Decrease the fuel counter 
        self.fuel_left -= 1 


        # apply the action to the vehicle
        if action == 0:
            if self.vehicle.y < self.y_max:
                self.vehicle.move(0,90)
            else:
                reward += -1000
        elif action == 1:
            if self.vehicle.y > self.y_min + 90 -1:
                self.vehicle.move(0,-90)
            else:
                reward += -1000
        elif action == 2:
            if self.vehicle.x < self.x_max:
                self.vehicle.move(90,0)
            else:
                reward += -1000
        elif action == 3:
            if self.vehicle.x > self.x_min + 90 -1:
                self.vehicle.move(-90,0)
            else:
                reward += -1000
        elif action == 4:
            if self.vehicle.y < self.y_max and self.vehicle.x < self.x_max:
                self.vehicle.move(0,90)
                self.vehicle.move(90,0)
            else:
                reward += -1000
        elif action == 5:
            if self.vehicle.y > self.y_min + 90 -1 and self.vehicle.x < self.x_max:
                self.vehicle.move(0,-90)
                self.vehicle.move(90,0)
            else:
                reward += -1000
        elif action == 6:
            if self.vehicle.y < self.y_max and self.vehicle.x > self.x_min + 90 -1:
                self.vehicle.move(0,90)
                self.vehicle.move(-90,0)
            else:
                reward += -1000
        elif action == 7:
            if self.vehicle.y > self.y_min + 90 -1 and self.vehicle.x > self.x_min + 90 -1:
                self.vehicle.move(0,-90)
                self.vehicle.move(-90,0)
            else:
                reward += -1000

        # Check if the vehicle is visiting a new cell
        previously_visited = False
        for cell in self.visited:
            if self.vehicle.x == cell.x and self.vehicle.y == cell.y:
                previously_visited = True
                break

        if not previously_visited:                               
            spawned_visit = Visited("visit_{}".format(self.visited_count), self.x_max, self.x_min, self.y_max, self.y_min)
            self.visited_count += 1
            spawned_visit.set_position(self.vehicle.x, self.vehicle.y)
            self.visited.append(spawned_visit)
       

            # Reward for executing a step towards a new cell
            reward += 25
        else:
            # Reward for executing a step towards a previously visited cell 
            reward += -5
        
        

        # Draw elements on the canvas
        self.draw_elements_on_canvas()

        # If out of fuel, end the episode.
        if self.fuel_left == 0:
            done = True
            reward += -30000 # Penalty for running out of fuel before reaching the goal
        
        if self.visited_count >= 90: # 90 for training, 100 for testing
            done = True
            reward += 100000 # Reward for reaching the goal
        #cv2.imshow("resized",cv2.resize(self.canvas, (45,45)))

        # Increment the episodic return
        self.ep_return += reward

        return cv2.resize(self.canvas, (45,45)), reward, done, {}
    
    
    #def clamp(self, n, minn, maxn):
    #    return max(min(maxn, n), minn)

# %%
class Point(object):
    def __init__(self, name, x_max, x_min, y_max, y_min):
        self.x = 0
        self.y = 0
        self.orientation = 0
        self.x_min = x_min
        self.x_max = x_max
        self.y_min = y_min
        self.y_max = y_max
        self.name = name
    
    def set_position(self, x, y):
        self.x = self.clamp(x, self.x_min, self.x_max - self.icon_w)
        self.y = self.clamp(y, self.y_min, self.y_max - self.icon_h)
    
    def get_position(self):
        return (self.x, self.y)
    
    def move(self, del_x, del_y):
        self.x += del_x
        self.y += del_y
        
        self.x = self.clamp(self.x, self.x_min, self.x_max - self.icon_w)
        self.y = self.clamp(self.y, self.y_min, self.y_max - self.icon_h)
    
    def clamp(self, n, minn, maxn):
        return max(min(maxn, n), minn)

# %%
class Vehicle(Point):
    def __init__(self, name, x_max, x_min, y_max, y_min):
        super(Vehicle, self).__init__(name, x_max, x_min, y_max, y_min)
        self.icon = cv2.imread("data/vehicle_ed.png") #/ 255.0 # , cv2.IMREAD_GRAYSCALE
        self.icon_w = 90
        self.icon_h = 90
        self.icon = cv2.resize(self.icon, (self.icon_h, self.icon_w))

class Visited(Point):
    def __init__(self, name, x_max, x_min, y_max, y_min):
        super(Visited, self).__init__(name, x_max, x_min, y_max, y_min)
        self.icon_w = 90
        self.icon_h = 90
        self.icon = 125*np.ones((self.icon_w, self.icon_h, 3), dtype=np.uint8)
        self.icon[:,:,1] = 255
        self.icon[::20,::20,:] = 0
        self.icon = cv2.resize(self.icon, (self.icon_h, self.icon_w))

# %% [markdown]
# # LEARNING

# %%
from typing import Callable

def make_env(env_id, rank: int, seed: int = 0) -> Callable:
    """
    Utility function for multiprocessed env.
    
    :param env_id: (str) the environment ID
    :param num_env: (int) the number of environment you wish to have in subprocesses
    :param seed: (int) the inital seed for RNG
    :param rank: (int) index of the subprocess
    :return: (Callable)
    """
    def _init() -> gym.Env:
        env = VehicleArea()
        env.seed(seed + rank)
        return env
    set_random_seed(seed)
    return _init

# %%
env = VehicleArea()

# %%
from stable_baselines3.common.env_checker import check_env
check_env(env)

# %%
model = DQN("CnnPolicy", env, verbose=1, optimize_memory_usage=True,exploration_fraction=0.4, exploration_final_eps=0.2) #, gamma=0.999, exploration_fraction=0.2, exploration_final_eps=0.5)
#, exploration_initial_eps=0.999 ,exploration_final_eps=0.6)#, learning_rate=0.000001)#, gamma=0.999, learning_rate=0.001)
model.learn(total_timesteps=10000000, log_interval=4)
model.save("data/dqn_vehicle_area_model_cnn")
#model = DQN.load("data/dqn_vehicle_area_model_cnn_1st_success")
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 474      |
# |    ep_rew_mean      | 7.83e+04 |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 1951     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1897     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 496      |
# |    ep_rew_mean      | 7.11e+04 |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 2054     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3968     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 574      |
# |    ep_rew_mean      | 6.77e+04 |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2044     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 6893     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 613      |
# |    ep_rew_mean      | 5.78e+04 |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 2007     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 9807     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 591      |
# |    ep_rew_mean      | 6.21e+04 |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 2035     |
# |    time_elapsed     | 5        |
# |    total_timesteps  | 11825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 592      |
# |    ep_rew_mean      | 6.27e+04 |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 2042     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 14215    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 577      |
# |    ep_rew_mean      | 6.4e+04  |
# |    exploration_rate | 0.997    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 2045     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 16150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 586      |
# |    ep_rew_mean      | 6.27e+04 |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2030     |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 18754    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 586      |
# |    ep_rew_mean      | 6.23e+04 |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 2030     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 21092    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 590      |
# |    ep_rew_mean      | 5.97e+04 |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 2032     |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 23585    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 590      |
# |    ep_rew_mean      | 6e+04    |
# |    exploration_rate | 0.995    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 2029     |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 25970    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 586      |
# |    ep_rew_mean      | 6.07e+04 |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 2033     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 28145    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 584      |
# |    ep_rew_mean      | 6.18e+04 |
# |    exploration_rate | 0.994    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 2039     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 30384    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 585      |
# |    ep_rew_mean      | 6.12e+04 |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 2048     |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 32785    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 591      |
# |    ep_rew_mean      | 6.1e+04  |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 2056     |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 35467    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 599      |
# |    ep_rew_mean      | 5.8e+04  |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 2061     |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 38315    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 588      |
# |    ep_rew_mean      | 5.96e+04 |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 2063     |
# |    time_elapsed     | 19       |
# |    total_timesteps  | 39980    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 580      |
# |    ep_rew_mean      | 6.06e+04 |
# |    exploration_rate | 0.992    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 2065     |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 41742    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 579      |
# |    ep_rew_mean      | 6.13e+04 |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 2063     |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 44025    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 582      |
# |    ep_rew_mean      | 6.07e+04 |
# |    exploration_rate | 0.991    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 2059     |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 46558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 588      |
# |    ep_rew_mean      | 5.78e+04 |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 2060     |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 49416    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 585      |
# |    ep_rew_mean      | 5.82e+04 |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1950     |
# |    time_elapsed     | 26       |
# |    total_timesteps  | 51475    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 64.3     |
# |    n_updates        | 368      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 580      |
# |    ep_rew_mean      | 5.89e+04 |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1833     |
# |    time_elapsed     | 29       |
# |    total_timesteps  | 53361    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.9     |
# |    n_updates        | 840      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 578      |
# |    ep_rew_mean      | 5.95e+04 |
# |    exploration_rate | 0.989    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1721     |
# |    time_elapsed     | 32       |
# |    total_timesteps  | 55536    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.6     |
# |    n_updates        | 1383     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 578      |
# |    ep_rew_mean      | 6e+04    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1626     |
# |    time_elapsed     | 35       |
# |    total_timesteps  | 57782    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 67       |
# |    n_updates        | 1945     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 578      |
# |    ep_rew_mean      | 6e+04    |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1562     |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 59652    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.9     |
# |    n_updates        | 2412     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 582      |
# |    ep_rew_mean      | 6.01e+04 |
# |    exploration_rate | 0.988    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1487     |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 62134    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35       |
# |    n_updates        | 3033     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 579      |
# |    ep_rew_mean      | 5.85e+04 |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1418     |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 64840    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.2e+03  |
# |    n_updates        | 3709     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 577      |
# |    ep_rew_mean      | 5.93e+04 |
# |    exploration_rate | 0.987    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1362     |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 67485    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.58     |
# |    n_updates        | 4371     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 583      |
# |    ep_rew_mean      | 5.83e+04 |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1314     |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 70139    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35       |
# |    n_updates        | 5034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 580      |
# |    ep_rew_mean      | 5.87e+04 |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1280     |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 72213    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.61     |
# |    n_updates        | 5553     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 581      |
# |    ep_rew_mean      | 5.89e+04 |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1251     |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 74228    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.13e+03 |
# |    n_updates        | 6056     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 577      |
# |    ep_rew_mean      | 5.92e+04 |
# |    exploration_rate | 0.985    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1221     |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 76490    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.7      |
# |    n_updates        | 6622     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 574      |
# |    ep_rew_mean      | 5.95e+04 |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1197     |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 78505    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 7.31     |
# |    n_updates        | 7126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 575      |
# |    ep_rew_mean      | 6.05e+04 |
# |    exploration_rate | 0.984    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1170     |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 81038    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.1      |
# |    n_updates        | 7759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 571      |
# |    ep_rew_mean      | 6.11e+04 |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1149     |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 83089    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 97.5     |
# |    n_updates        | 8272     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 572      |
# |    ep_rew_mean      | 6.14e+04 |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1129     |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 85354    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.1     |
# |    n_updates        | 8838     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 575      |
# |    ep_rew_mean      | 6.1e+04  |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1109     |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 87880    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 66.3     |
# |    n_updates        | 9469     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 574      |
# |    ep_rew_mean      | 6.18e+04 |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1092     |
# |    time_elapsed     | 82       |
# |    total_timesteps  | 90227    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 94.2     |
# |    n_updates        | 10056    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 568      |
# |    ep_rew_mean      | 6.27e+04 |
# |    exploration_rate | 0.982    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1077     |
# |    time_elapsed     | 85       |
# |    total_timesteps  | 92288    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 2.63     |
# |    n_updates        | 10571    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 561      |
# |    ep_rew_mean      | 6.51e+04 |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1064     |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 94384    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.7     |
# |    n_updates        | 11095    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 571      |
# |    ep_rew_mean      | 6.25e+04 |
# |    exploration_rate | 0.981    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1048     |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 97093    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.16e+03 |
# |    n_updates        | 11773    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 580      |
# |    ep_rew_mean      | 6.05e+04 |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1034     |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 99783    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 164      |
# |    n_updates        | 12445    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 583      |
# |    ep_rew_mean      | 6.01e+04 |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1021     |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 102290   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 98.4     |
# |    n_updates        | 13072    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 578      |
# |    ep_rew_mean      | 6.07e+04 |
# |    exploration_rate | 0.979    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1011     |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 104314   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36       |
# |    n_updates        | 13578    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 584      |
# |    ep_rew_mean      | 6.2e+04  |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 996      |
# |    time_elapsed     | 108      |
# |    total_timesteps  | 107839   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 66       |
# |    n_updates        | 14459    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 588      |
# |    ep_rew_mean      | 6.2e+04  |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 986      |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 110285   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 65.9     |
# |    n_updates        | 15071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 588      |
# |    ep_rew_mean      | 6.21e+04 |
# |    exploration_rate | 0.978    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 978      |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 112150   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 65.7     |
# |    n_updates        | 15537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 588      |
# |    ep_rew_mean      | 6.21e+04 |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 970      |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 114346   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.9     |
# |    n_updates        | 16086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 588      |
# |    ep_rew_mean      | 6.15e+04 |
# |    exploration_rate | 0.977    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 962      |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 116565   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 100      |
# |    n_updates        | 16641    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 586      |
# |    ep_rew_mean      | 6.18e+04 |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 957      |
# |    time_elapsed     | 123      |
# |    total_timesteps  | 118242   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 98       |
# |    n_updates        | 17060    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 580      |
# |    ep_rew_mean      | 6.18e+04 |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 951      |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 120087   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 96.9     |
# |    n_updates        | 17521    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 576      |
# |    ep_rew_mean      | 6.25e+04 |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 944      |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 122390   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.38     |
# |    n_updates        | 18097    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 568      |
# |    ep_rew_mean      | 6.37e+04 |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 939      |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 124318   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 158      |
# |    n_updates        | 18579    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 566      |
# |    ep_rew_mean      | 6.36e+04 |
# |    exploration_rate | 0.975    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 932      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 126737   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 9.23     |
# |    n_updates        | 19184    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 566      |
# |    ep_rew_mean      | 6.32e+04 |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 927      |
# |    time_elapsed     | 138      |
# |    total_timesteps  | 128772   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.1     |
# |    n_updates        | 19692    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 572      |
# |    ep_rew_mean      | 6.3e+04  |
# |    exploration_rate | 0.974    |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 920      |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 131457   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 38.5     |
# |    n_updates        | 20364    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 570      |
# |    ep_rew_mean      | 6.35e+04 |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 915      |
# |    time_elapsed     | 145      |
# |    total_timesteps  | 133474   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.2     |
# |    n_updates        | 20868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 572      |
# |    ep_rew_mean      | 6.35e+04 |
# |    exploration_rate | 0.973    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 910      |
# |    time_elapsed     | 149      |
# |    total_timesteps  | 135683   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 95.6     |
# |    n_updates        | 21420    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 570      |
# |    ep_rew_mean      | 6.37e+04 |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 905      |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 138027   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34       |
# |    n_updates        | 22006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 573      |
# |    ep_rew_mean      | 6.36e+04 |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 900      |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 140421   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.4     |
# |    n_updates        | 22605    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 574      |
# |    ep_rew_mean      | 6.35e+04 |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 895      |
# |    time_elapsed     | 159      |
# |    total_timesteps  | 142727   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 1.99     |
# |    n_updates        | 23181    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 573      |
# |    ep_rew_mean      | 6.35e+04 |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 890      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 145224   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 63.8     |
# |    n_updates        | 23805    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 569      |
# |    ep_rew_mean      | 6.38e+04 |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 887      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 147131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 41.6     |
# |    n_updates        | 24282    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 565      |
# |    ep_rew_mean      | 6.34e+04 |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 884      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 148800   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 32.6     |
# |    n_updates        | 24699    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 561      |
# |    ep_rew_mean      | 6.35e+04 |
# |    exploration_rate | 0.97     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 881      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 150519   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 64.4     |
# |    n_updates        | 25129    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 557      |
# |    ep_rew_mean      | 6.55e+04 |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 877      |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 152817   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 161      |
# |    n_updates        | 25704    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 555      |
# |    ep_rew_mean      | 6.69e+04 |
# |    exploration_rate | 0.969    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 873      |
# |    time_elapsed     | 177      |
# |    total_timesteps  | 155262   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.19e+03 |
# |    n_updates        | 26315    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 554      |
# |    ep_rew_mean      | 6.72e+04 |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 869      |
# |    time_elapsed     | 181      |
# |    total_timesteps  | 157663   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36.6     |
# |    n_updates        | 26915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 554      |
# |    ep_rew_mean      | 6.77e+04 |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 866      |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 159760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36.3     |
# |    n_updates        | 27439    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 538      |
# |    ep_rew_mean      | 6.93e+04 |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 864      |
# |    time_elapsed     | 187      |
# |    total_timesteps  | 161677   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.1     |
# |    n_updates        | 27919    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 538      |
# |    ep_rew_mean      | 6.97e+04 |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 860      |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 164099   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.3     |
# |    n_updates        | 28524    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 549      |
# |    ep_rew_mean      | 6.71e+04 |
# |    exploration_rate | 0.967    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 856      |
# |    time_elapsed     | 195      |
# |    total_timesteps  | 167089   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 96.9     |
# |    n_updates        | 29272    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 544      |
# |    ep_rew_mean      | 6.73e+04 |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 854      |
# |    time_elapsed     | 197      |
# |    total_timesteps  | 168775   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 96.6     |
# |    n_updates        | 29693    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 547      |
# |    ep_rew_mean      | 6.77e+04 |
# |    exploration_rate | 0.966    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 851      |
# |    time_elapsed     | 201      |
# |    total_timesteps  | 171281   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.4     |
# |    n_updates        | 30320    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 550      |
# |    ep_rew_mean      | 6.72e+04 |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 848      |
# |    time_elapsed     | 204      |
# |    total_timesteps  | 173210   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.8     |
# |    n_updates        | 30802    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 563      |
# |    ep_rew_mean      | 6.67e+04 |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 844      |
# |    time_elapsed     | 208      |
# |    total_timesteps  | 176346   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 32.9     |
# |    n_updates        | 31586    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 558      |
# |    ep_rew_mean      | 6.82e+04 |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 842      |
# |    time_elapsed     | 211      |
# |    total_timesteps  | 178180   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 65       |
# |    n_updates        | 32044    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 556      |
# |    ep_rew_mean      | 6.81e+04 |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 840      |
# |    time_elapsed     | 214      |
# |    total_timesteps  | 179887   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.04     |
# |    n_updates        | 32471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 552      |
# |    ep_rew_mean      | 6.9e+04  |
# |    exploration_rate | 0.964    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 838      |
# |    time_elapsed     | 217      |
# |    total_timesteps  | 181985   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 128      |
# |    n_updates        | 32996    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 551      |
# |    ep_rew_mean      | 6.95e+04 |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 836      |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 183833   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.19     |
# |    n_updates        | 33458    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 541      |
# |    ep_rew_mean      | 7e+04    |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 834      |
# |    time_elapsed     | 222      |
# |    total_timesteps  | 185538   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 63       |
# |    n_updates        | 33884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 538      |
# |    ep_rew_mean      | 7.02e+04 |
# |    exploration_rate | 0.963    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 831      |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 187274   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 130      |
# |    n_updates        | 34318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 534      |
# |    ep_rew_mean      | 7.05e+04 |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 829      |
# |    time_elapsed     | 228      |
# |    total_timesteps  | 189077   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.1     |
# |    n_updates        | 34769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 534      |
# |    ep_rew_mean      | 7.1e+04  |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 826      |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 191382   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 69       |
# |    n_updates        | 35345    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 525      |
# |    ep_rew_mean      | 7.13e+04 |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 823      |
# |    time_elapsed     | 234      |
# |    total_timesteps  | 192948   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 33.3     |
# |    n_updates        | 35736    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 524      |
# |    ep_rew_mean      | 7.1e+04  |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 821      |
# |    time_elapsed     | 237      |
# |    total_timesteps  | 195077   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 158      |
# |    n_updates        | 36269    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 521      |
# |    ep_rew_mean      | 7.09e+04 |
# |    exploration_rate | 0.961    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 818      |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 197277   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.4      |
# |    n_updates        | 36819    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 520      |
# |    ep_rew_mean      | 7.06e+04 |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 816      |
# |    time_elapsed     | 243      |
# |    total_timesteps  | 199113   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 98.8     |
# |    n_updates        | 37278    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 525      |
# |    ep_rew_mean      | 7.11e+04 |
# |    exploration_rate | 0.96     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 814      |
# |    time_elapsed     | 247      |
# |    total_timesteps  | 201304   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 128      |
# |    n_updates        | 37825    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 537      |
# |    ep_rew_mean      | 6.94e+04 |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 811      |
# |    time_elapsed     | 251      |
# |    total_timesteps  | 204252   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 31.6     |
# |    n_updates        | 38562    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 538      |
# |    ep_rew_mean      | 6.9e+04  |
# |    exploration_rate | 0.959    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 809      |
# |    time_elapsed     | 255      |
# |    total_timesteps  | 206629   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 129      |
# |    n_updates        | 39157    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 538      |
# |    ep_rew_mean      | 6.88e+04 |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 807      |
# |    time_elapsed     | 258      |
# |    total_timesteps  | 209037   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 35.4     |
# |    n_updates        | 39759    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 537      |
# |    ep_rew_mean      | 6.89e+04 |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 806      |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 211363   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 96.2     |
# |    n_updates        | 40340    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 535      |
# |    ep_rew_mean      | 6.89e+04 |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 804      |
# |    time_elapsed     | 265      |
# |    total_timesteps  | 213258   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.58     |
# |    n_updates        | 40814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 541      |
# |    ep_rew_mean      | 6.86e+04 |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 802      |
# |    time_elapsed     | 268      |
# |    total_timesteps  | 215793   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 4.76     |
# |    n_updates        | 41448    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 538      |
# |    ep_rew_mean      | 6.88e+04 |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 800      |
# |    time_elapsed     | 272      |
# |    total_timesteps  | 217934   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.2     |
# |    n_updates        | 41983    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 531      |
# |    ep_rew_mean      | 7.11e+04 |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 798      |
# |    time_elapsed     | 275      |
# |    total_timesteps  | 220140   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 5.73     |
# |    n_updates        | 42534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 535      |
# |    ep_rew_mean      | 7.11e+04 |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 796      |
# |    time_elapsed     | 279      |
# |    total_timesteps  | 222285   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 68.6     |
# |    n_updates        | 43071    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 527      |
# |    ep_rew_mean      | 7.18e+04 |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 795      |
# |    time_elapsed     | 281      |
# |    total_timesteps  | 223946   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 3.2e+03  |
# |    n_updates        | 43486    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 537      |
# |    ep_rew_mean      | 7.12e+04 |
# |    exploration_rate | 0.955    |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 792      |
# |    time_elapsed     | 286      |
# |    total_timesteps  | 226920   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 34.8     |
# |    n_updates        | 44229    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 529      |
# |    ep_rew_mean      | 7.21e+04 |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 790      |
# |    time_elapsed     | 290      |
# |    total_timesteps  | 229268   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 95.3     |
# |    n_updates        | 44816    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 535      |
# |    ep_rew_mean      | 7.18e+04 |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 788      |
# |    time_elapsed     | 293      |
# |    total_timesteps  | 231728   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.8     |
# |    n_updates        | 45431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 546      |
# |    ep_rew_mean      | 7.09e+04 |
# |    exploration_rate | 0.953    |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 786      |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 234442   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 40.1     |
# |    n_updates        | 46110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 556      |
# |    ep_rew_mean      | 6.92e+04 |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 784      |
# |    time_elapsed     | 302      |
# |    total_timesteps  | 237563   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 97.7     |
# |    n_updates        | 46890    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 563      |
# |    ep_rew_mean      | 6.93e+04 |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 782      |
# |    time_elapsed     | 306      |
# |    total_timesteps  | 240171   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 37.6     |
# |    n_updates        | 47542    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 568      |
# |    ep_rew_mean      | 6.87e+04 |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 780      |
# |    time_elapsed     | 310      |
# |    total_timesteps  | 242345   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 36.1     |
# |    n_updates        | 48086    |
# ----------------------------------

# %%
from IPython import display


obs = env.reset()


while True:
    action, _states = model.predict(obs, deterministic=True)
    #action = env.action_space.sample()
    obs, reward, done, info = env.step(action)
    
    # Render the game
    env.render()
    
    
    if done == True:
        print('reward= ',reward)
        print('fuel= ',env.fuel_left)
        break

env.close()

# %%
###from gym.wrappers import Monitor
###env = Monitor(env, './data/video_4.mp4', force=True)
###obs = env.reset()
###model = DQN.load("data/dqn_vehicle_area_model_cnn")
###time.sleep(4)
###while True:
###    action, _states = model.predict(obs)#, deterministic=True)
###    #action = env.action_space.sample()
###    obs, reward, done, info = env.step(action)
###    
###    # Render the game
###    env.render()
###    #print('reward= ',reward)
###    time.sleep(0.1)
###    if done == True:
###        break
###
###env.close()
